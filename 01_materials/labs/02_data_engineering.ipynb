# %%
# %load_ext dotenv
# %dotenv
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
# ...
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %%
src = os.getenv('SRC_DIR')
print(src)
# Out:
# ../../05_src/

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
# ...
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
px
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-12-02 00:00:00-05:00   17.405168   17.602613   17.181210   17.193998
# 2013-12-03 00:00:00-05:00   17.414522   17.666555   17.395184   17.664682
# 2013-12-04 00:00:00-05:00   17.639100   17.754199   17.493121   17.623505
# 2013-12-05 00:00:00-05:00   17.862131   17.939799   17.667493   17.713968
# 2013-12-06 00:00:00-05:00   17.648149   17.678094   17.454136   17.468170
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00-05:00  194.482008  195.528042  192.379984  193.435974
# 2024-01-26 00:00:00-05:00  193.535609  194.023747  191.214415  191.692596
# 2024-01-29 00:00:00-05:00  191.284128  191.473412  188.863322  191.005188
# 2024-01-30 00:00:00-05:00  190.218194  191.074943  186.761310  187.329147
# 2024-01-31 00:00:00-05:00  186.332931  186.392717  183.653113  183.702911
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-12-02 00:00:00-05:00  472544800        0.0           0.0
# 2013-12-03 00:00:00-05:00  450968000        0.0           0.0
# 2013-12-04 00:00:00-05:00  377809600        0.0           0.0
# 2013-12-05 00:00:00-05:00  447580000        0.0           0.0
# 2013-12-06 00:00:00-05:00  344352400        0.0           0.0
# ...                              ...        ...           ...
# 2024-01-25 00:00:00-05:00   54822100        0.0           0.0
# 2024-01-26 00:00:00-05:00   44594000        0.0           0.0
# 2024-01-29 00:00:00-05:00   47145600        0.0           0.0
# 2024-01-30 00:00:00-05:00   55859400        0.0           0.0
# 2024-01-31 00:00:00-05:00   55467800        0.0           0.0
#
# [2558 rows x 7 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %%
tickers
# Out:
#     ticker                                Security             GICS Sector  \
# 268    JCI                        Johnson Controls             Industrials
# 73     BSX                       Boston Scientific             Health Care
# 289    LIN                               Linde plc               Materials
# 155    DOW                                Dow Inc.               Materials
# 104    CVX                     Chevron Corporation                  Energy
# 280    KHC                             Kraft Heinz        Consumer Staples
# 392     RL                Ralph Lauren Corporation  Consumer Discretionary
# 124     ED                     Consolidated Edison               Utilities
# 68      BX                              Blackstone              Financials
# 244    IBM                                     IBM  Information Technology
# 9        A                    Agilent Technologies             Health Care
# 195    FIS  Fidelity National Information Services              Financials
# 304    MAS                                   Masco             Industrials
# 84     CPB                   Campbell Soup Company        Consumer Staples
# 373    PNW                           Pinnacle West               Utilities
# 390   QCOM                                Qualcomm  Information Technology
# 498    YUM                             Yum! Brands  Consumer Discretionary
# 30     AWK                    American Water Works               Utilities
# 317     MU                       Micron Technology  Information Technology
# 407    RCL                   Royal Caribbean Group  Consumer Discretionary
# 493    WTW                    Willis Towers Watson              Financials
# 494    GWW                          W. W. Grainger             Industrials
# 225    HAS                                  Hasbro  Consumer Discretionary
# 227   PEAK                              Healthpeak             Real Estate
# 76      BR          Broadridge Financial Solutions             Industrials
# 464    VLO                           Valero Energy                  Energy
# 473   VICI                         Vici Properties             Real Estate
# 402    RHI                             Robert Half             Industrials
# 101    CRL              Charles River Laboratories             Health Care
# 335    NEM                                 Newmont               Materials
# 296    LYB                          LyondellBasell               Materials
# 222     GS                           Goldman Sachs              Financials
# 474      V                               Visa Inc.              Financials
# 173   EPAM                            EPAM Systems  Information Technology
# 2      ABT                                  Abbott             Health Care
# 334   NFLX                                 Netflix  Communication Services
# 272   KVUE                                  Kenvue        Consumer Staples
# 70    BKNG                        Booking Holdings  Consumer Discretionary
# 210     IT                                 Gartner  Information Technology
# 63     BBY                                Best Buy  Consumer Discretionary
# 347    NUE                                   Nucor               Materials
# 93    CBRE                              CBRE Group             Real Estate
# 488    WDC                         Western Digital  Information Technology
# 185   EXPE                           Expedia Group  Consumer Discretionary
# 33    AMGN                                   Amgen             Health Care
# 77     BRO                           Brown & Brown              Financials
# 0      MMM                                      3M             Industrials
# 11    ABNB                                  Airbnb  Consumer Discretionary
# 310    MDT                               Medtronic             Health Care
# 22    AMZN                                  Amazon  Consumer Discretionary
#
#                                 GICS Sub-Industry  \
# 268                             Building Products
# 73                          Health Care Equipment
# 289                              Industrial Gases
# 155                           Commodity Chemicals
# 104                          Integrated Oil & Gas
# 280                        Packaged Foods & Meats
# 392           Apparel, Accessories & Luxury Goods
# 124                               Multi-Utilities
# 68               Asset Management & Custody Banks
# 244                IT Consulting & Other Services
# 9                  Life Sciences Tools & Services
# 195     Transaction & Payment Processing Services
# 304                             Building Products
# 84                         Packaged Foods & Meats
# 373                               Multi-Utilities
# 390                                Semiconductors
# 498                                   Restaurants
# 30                                Water Utilities
# 317                                Semiconductors
# 407                Hotels, Resorts & Cruise Lines
# 493                             Insurance Brokers
# 494  Industrial Machinery & Supplies & Components
# 225                              Leisure Products
# 227                             Health Care REITs
# 76          Data Processing & Outsourced Services
# 464                Oil & Gas Refining & Marketing
# 473                          Hotel & Resort REITs
# 402          Human Resource & Employment Services
# 101                Life Sciences Tools & Services
# 335                                          Gold
# 296                           Specialty Chemicals
# 222                Investment Banking & Brokerage
# 474     Transaction & Payment Processing Services
# 173                IT Consulting & Other Services
# 2                           Health Care Equipment
# 334                        Movies & Entertainment
# 272                        Personal Care Products
# 70                 Hotels, Resorts & Cruise Lines
# 210                IT Consulting & Other Services
# 63                  Computer & Electronics Retail
# 347                                         Steel
# 93                           Real Estate Services
# 488    Technology Hardware, Storage & Peripherals
# 185                Hotels, Resorts & Cruise Lines
# 33                                  Biotechnology
# 77                              Insurance Brokers
# 0                        Industrial Conglomerates
# 11                 Hotels, Resorts & Cruise Lines
# 310                         Health Care Equipment
# 22                               Broadline Retail
#
#                            Headquarters Location  Date added      CIK  \
# 268                                Cork, Ireland       40417   833444
# 73                    Marlborough, Massachusetts       34754   885725
# 289                    Guildford, United Kingdom       33786  1707925
# 155                            Midland, Michigan       43556  1751788
# 104                        San Ramon, California       20883    93410
# 280  Chicago, Illinois; Pittsburgh, Pennsylvania       42191  1637459
# 392                      New York City, New York       39115  1037038
# 124                      New York City, New York       20883  1047862
# 68                       New York City, New York       45187  1393818
# 244                             Armonk, New York       20883    51143
# 9                        Santa Clara, California       36682  1090872
# 195                        Jacksonville, Florida       39031  1136893
# 304                            Livonia, Michigan       29767    62996
# 84                            Camden, New Jersey       20883    16732
# 373                             Phoenix, Arizona       36437   764622
# 390                        San Diego, California       36363   804328
# 498                         Louisville, Kentucky       35709  1041061
# 30                            Camden, New Jersey       42433  1410636
# 317                                 Boise, Idaho       34604   723125
# 407                               Miami, Florida       41978   884887
# 493                       London, United Kingdom       42374  1140536
# 494                        Lake Forest, Illinois       29767   277135
# 225                      Pawtucket, Rhode Island       30955    46080
# 227                       Long Beach, California       39538   765880
# 76                        Lake Success, New York       43269  1383312
# 464                           San Antonio, Texas       37610  1035002
# 473                      New York City, New York       44720  1705696
# 402                       Menlo Park, California       36865   315213
# 101                    Wilmington, Massachusetts       44330  1100682
# 335                             Denver, Colorado       25384  1164727
# 296                       Rotterdam, Netherlands       41157  1489393
# 222                      New York City, New York       37459   886982
# 474                    San Francisco, California       40168  1403161
# 173                        Newtown, Pennsylvania       44544  1352010
# 2                        North Chicago, Illinois       20883     1800
# 334                        Los Gatos, California       40532  1065280
# 272                         Skillman, New Jersey       45163  1944048
# 70                          Norwalk, Connecticut       40123  1075531
# 210                        Stamford, Connecticut       42830   749251
# 63                          Richfield, Minnesota       36340   764478
# 347                    Charlotte, North Carolina       31167    73309
# 93                                 Dallas, Texas       39031  1138118
# 488                         San Jose, California       39995   106040
# 185                          Seattle, Washington       39357  1324424
# 33                     Thousand Oaks, California       33605   318154
# 77                        Daytona Beach, Florida       44459    79282
# 0                          Saint Paul, Minnesota       20883    66740
# 11                     San Francisco, California       45187  1559720
# 310                              Dublin, Ireland       31716  1613103
# 22                           Seattle, Washington       38674  1018724
#
#                               Founded
# 268                              1885
# 73                               1979
# 289                              1879
# 155                       2019 (1897)
# 104                              1879
# 280                       2015 (1869)
# 392                              1967
# 124                              1823
# 68                               1985
# 244                              1911
# 9                                1999
# 195                              1968
# 304                              1929
# 84                               1869
# 373                              1985
# 390                              1985
# 498                              1997
# 30                               1886
# 317                              1978
# 407                              1997
# 493                              2016
# 494                              1927
# 225                              1923
# 227                              1985
# 76                               1962
# 464                              1980
# 473                              2017
# 402                              1948
# 101                              1947
# 335                              1921
# 296                              2007
# 222                              1869
# 474                              1958
# 173                              1993
# 2                                1888
# 334                              1997
# 272  2022 (Johnson & Johnson spinoff)
# 70                               1996
# 210                              1979
# 63                               1966
# 347                              1940
# 93                               1906
# 488                              1970
# 185                              1996
# 33                               1980
# 77                               1939
# 0                                1902
# 11                               2008
# 310                              1949
# 22                               1994

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; no timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 5.58452296257019 seconds.
# Csv file size 14.154689999999999 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\Admin\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14580\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 1.8415000438690186 seconds.
# Parquet file size 5.561757 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14580\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.875487   35.005933   34.640679
# A      2013-12-03 00:00:00-05:00   34.516759   34.679822   34.281951
# A      2013-12-04 00:00:00-05:00   34.464560   35.110283   34.386293
# A      2013-12-05 00:00:00-05:00   34.797210   35.090719   34.647194
# A      2013-12-06 00:00:00-05:00   35.064621   35.827743   35.064621
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002206  128.760844  126.770657
# YUM    2024-01-29 00:00:00-05:00  127.194317  128.622910  126.396261
# YUM    2024-01-30 00:00:00-05:00  128.435723  129.283029  127.667238
# YUM    2024-01-31 00:00:00-05:00  129.509619  130.031795  127.351944
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.705902  2039962        0.0           0.0  2013          NaN
# A        34.523281  3462706        0.0           0.0  2013    34.705902
# A        34.947220  3377288        0.0           0.0  2013    34.523281
# A        34.895046  2530939        0.0           0.0  2013    34.947220
# A        35.762520  4268513        0.0           0.0  2013    34.895046
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.297791  1871700        0.0           0.0  2024   127.529297
# YUM     127.184456  1157000        0.0           0.0  2024   128.297791
# YUM     128.622910  1482100        0.0           0.0  2024   127.184456
# YUM     128.691879  1421500        0.0           0.0  2024   128.622910
# YUM     127.578560  2154200        0.0           0.0  2024   128.691879
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-10-25 14:38:31,571, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-25 14:38:31,571, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-25 14:38:31,575, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-25 14:38:31,575, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-25 14:38:31,591, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-25 14:38:31,591, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-25 14:38:31,599, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-25 14:38:31,599, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-25 14:38:31,608, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:31,608, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:32,246, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-10-25 14:38:32,246, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-10-25 14:38:34,946, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-25 14:38:34,946, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-25 14:38:34,958, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:34,958, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:35,685, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-10-25 14:38:35,685, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-10-25 14:38:38,213, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-25 14:38:38,213, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-25 14:38:38,213, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:38,213, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:38,827, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-10-25 14:38:38,827, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-10-25 14:38:41,459, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-25 14:38:41,459, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-25 14:38:41,474, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:41,474, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:42,061, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-10-25 14:38:42,061, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-10-25 14:38:43,141, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-25 14:38:43,141, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-25 14:38:43,141, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:43,141, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:43,812, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-10-25 14:38:43,812, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-10-25 14:38:46,013, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-25 14:38:46,013, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-25 14:38:46,013, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:46,013, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:46,525, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-10-25 14:38:46,525, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-10-25 14:38:48,809, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-25 14:38:48,809, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-25 14:38:48,809, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:48,809, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:49,397, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-10-25 14:38:49,397, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-10-25 14:38:51,676, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-25 14:38:51,676, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-25 14:38:51,676, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:51,676, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:52,423, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-10-25 14:38:52,423, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-10-25 14:38:54,757, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-25 14:38:54,757, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-25 14:38:54,757, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:54,757, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:55,564, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-10-25 14:38:55,564, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-10-25 14:38:57,826, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-25 14:38:57,826, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-25 14:38:57,842, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-25
# 2024-10-25 14:38:57,842, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:38:58,507, data_manager.py, 82, INFO, Saving data for A by year
# 2024-10-25 14:38:58,507, data_manager.py, 82, INFO, Saving data for A by year
# 2024-10-25 14:39:00,960, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-25 14:39:00,960, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-25 14:39:00,975, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:00,975, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:02,060, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-10-25 14:39:02,060, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-10-25 14:39:04,375, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-25 14:39:04,375, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-25 14:39:04,375, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:04,375, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:04,842, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-10-25 14:39:04,842, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-10-25 14:39:05,359, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-25 14:39:05,359, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-25 14:39:05,359, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:05,359, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:05,977, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-10-25 14:39:05,977, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-10-25 14:39:08,426, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-25 14:39:08,426, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-25 14:39:08,426, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:08,426, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:09,159, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-10-25 14:39:09,159, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-10-25 14:39:11,577, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-25 14:39:11,577, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-25 14:39:11,593, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:11,593, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:12,240, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-10-25 14:39:12,240, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-10-25 14:39:14,556, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-25 14:39:14,556, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-25 14:39:14,556, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:14,556, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:15,244, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-10-25 14:39:15,244, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-10-25 14:39:18,044, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-25 14:39:18,044, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-25 14:39:18,044, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:18,044, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:18,609, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-10-25 14:39:18,609, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-10-25 14:39:19,877, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-25 14:39:19,877, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-25 14:39:19,892, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:19,892, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:20,923, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-10-25 14:39:20,923, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-10-25 14:39:23,225, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-25 14:39:23,225, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-25 14:39:23,225, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:23,225, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:24,145, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-10-25 14:39:24,145, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-10-25 14:39:26,978, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-25 14:39:26,978, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-25 14:39:26,978, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:26,978, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:27,757, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-10-25 14:39:27,757, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-10-25 14:39:29,710, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-25 14:39:29,710, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-25 14:39:29,710, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:29,710, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:30,442, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-10-25 14:39:30,442, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-10-25 14:39:32,374, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-25 14:39:32,374, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-25 14:39:32,374, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:32,374, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:33,309, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-10-25 14:39:33,309, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-10-25 14:39:35,589, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-25 14:39:35,589, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-25 14:39:35,589, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:35,589, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:36,007, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-10-25 14:39:36,007, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-10-25 14:39:38,475, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-25 14:39:38,475, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-25 14:39:38,477, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:38,477, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:38,857, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-10-25 14:39:38,857, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-10-25 14:39:40,077, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-25 14:39:40,077, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-25 14:39:40,077, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:40,077, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:40,788, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-10-25 14:39:40,788, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-10-25 14:39:43,106, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-25 14:39:43,106, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-25 14:39:43,106, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:43,106, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:43,659, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-10-25 14:39:43,659, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-10-25 14:39:45,493, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-25 14:39:45,493, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-25 14:39:45,509, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:45,509, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:46,257, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-10-25 14:39:46,257, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-10-25 14:39:48,588, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-25 14:39:48,588, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-25 14:39:48,588, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:48,588, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:49,789, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-10-25 14:39:49,789, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-10-25 14:39:52,505, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-25 14:39:52,505, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-25 14:39:52,505, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:52,505, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:53,271, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-10-25 14:39:53,271, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-10-25 14:39:55,742, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-25 14:39:55,742, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-25 14:39:55,742, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:55,742, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:56,390, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-10-25 14:39:56,390, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-10-25 14:39:58,741, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-25 14:39:58,741, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-25 14:39:58,741, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-25
# 2024-10-25 14:39:58,741, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:39:59,190, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-10-25 14:39:59,190, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-10-25 14:40:00,809, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-25 14:40:00,809, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-25 14:40:00,809, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:00,809, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:01,405, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-10-25 14:40:01,405, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-10-25 14:40:03,292, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-25 14:40:03,292, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-25 14:40:03,307, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:03,307, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:04,056, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-10-25 14:40:04,056, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-10-25 14:40:06,422, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-25 14:40:06,422, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-25 14:40:06,438, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:06,438, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:07,010, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-10-25 14:40:07,010, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-10-25 14:40:09,527, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-25 14:40:09,527, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-25 14:40:09,538, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:09,538, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:10,071, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-10-25 14:40:10,071, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-10-25 14:40:12,671, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-25 14:40:12,671, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-25 14:40:12,671, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:12,671, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:14,087, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-10-25 14:40:14,087, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-10-25 14:40:16,675, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-25 14:40:16,675, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-25 14:40:16,675, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:16,675, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:17,441, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-10-25 14:40:17,441, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-10-25 14:40:20,324, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-25 14:40:20,324, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-25 14:40:20,324, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:20,324, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:21,056, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-10-25 14:40:21,056, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-10-25 14:40:23,553, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-25 14:40:23,553, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-25 14:40:23,553, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:23,553, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:24,623, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-10-25 14:40:24,623, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-10-25 14:40:27,304, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-25 14:40:27,304, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-25 14:40:27,319, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:27,319, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:27,908, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-10-25 14:40:27,908, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-10-25 14:40:30,904, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-25 14:40:30,904, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-25 14:40:30,904, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:30,904, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:31,590, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-10-25 14:40:31,590, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-10-25 14:40:33,923, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-25 14:40:33,923, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-25 14:40:33,938, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:33,938, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:34,521, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-10-25 14:40:34,521, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-10-25 14:40:35,807, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-25 14:40:35,807, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-25 14:40:35,823, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:35,823, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:36,320, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-10-25 14:40:36,320, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-10-25 14:40:39,240, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-25 14:40:39,240, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-25 14:40:39,256, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:39,256, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:39,836, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-10-25 14:40:39,836, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-10-25 14:40:42,153, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-25 14:40:42,153, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-25 14:40:42,153, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:42,153, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:42,723, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-10-25 14:40:42,723, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-10-25 14:40:43,738, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-25 14:40:43,738, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-25 14:40:43,738, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:43,738, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:44,839, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-10-25 14:40:44,839, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-10-25 14:40:47,120, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-25 14:40:47,120, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-25 14:40:47,120, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:47,120, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:47,721, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-10-25 14:40:47,721, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-10-25 14:40:49,623, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-25 14:40:49,623, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-25 14:40:49,639, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:49,639, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:50,388, data_manager.py, 82, INFO, Saving data for T by year
# 2024-10-25 14:40:50,388, data_manager.py, 82, INFO, Saving data for T by year
# 2024-10-25 14:40:52,635, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-25 14:40:52,635, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-25 14:40:52,635, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:52,635, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:53,219, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-10-25 14:40:53,219, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-10-25 14:40:55,502, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-25 14:40:55,502, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-25 14:40:55,502, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:55,502, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:56,268, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-10-25 14:40:56,268, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-10-25 14:40:58,717, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-25 14:40:58,717, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-25 14:40:58,718, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-25
# 2024-10-25 14:40:58,718, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:40:59,552, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-10-25 14:40:59,552, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-10-25 14:41:01,952, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-25 14:41:01,952, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-25 14:41:01,968, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:01,968, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:02,434, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-10-25 14:41:02,434, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-10-25 14:41:04,768, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-25 14:41:04,768, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-25 14:41:04,768, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:04,768, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:05,552, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-10-25 14:41:05,552, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-10-25 14:41:07,775, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-25 14:41:07,775, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-25 14:41:07,775, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:07,775, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:08,518, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-10-25 14:41:08,518, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-10-25 14:41:10,767, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-25 14:41:10,767, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-25 14:41:10,774, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:10,774, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:11,252, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-10-25 14:41:11,252, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-10-25 14:41:13,618, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-25 14:41:13,618, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-25 14:41:13,618, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:13,618, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:14,434, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-10-25 14:41:14,434, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-10-25 14:41:16,667, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-25 14:41:16,667, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-25 14:41:16,675, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:16,675, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:18,451, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-10-25 14:41:18,451, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-10-25 14:41:21,018, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-25 14:41:21,018, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-25 14:41:21,018, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:21,018, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:21,684, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-10-25 14:41:21,684, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-10-25 14:41:24,051, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-25 14:41:24,051, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-25 14:41:24,051, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:24,051, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:25,003, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-10-25 14:41:25,003, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-10-25 14:41:27,484, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-25 14:41:27,484, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-25 14:41:27,484, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:27,484, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:28,334, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-10-25 14:41:28,334, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-10-25 14:41:30,617, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-25 14:41:30,617, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-25 14:41:30,617, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:30,617, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:31,434, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-10-25 14:41:31,434, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-10-25 14:41:33,717, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-25 14:41:33,717, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-25 14:41:33,717, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:33,717, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:34,600, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-10-25 14:41:34,600, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-10-25 14:41:36,933, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-25 14:41:36,933, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-25 14:41:36,949, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:36,949, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-10-25 14:41:38,517, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-10-25 14:41:38,517, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-10-25 14:41:38,533, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-10-25 14:41:38,533, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-10-25 14:41:38,533, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-25 14:41:38,533, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-25 14:41:38,550, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:38,550, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:39,183, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-10-25 14:41:39,183, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-10-25 14:41:41,433, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-25 14:41:41,433, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-25 14:41:41,433, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:41,433, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:41,966, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-10-25 14:41:41,966, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-10-25 14:41:44,375, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-25 14:41:44,375, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-25 14:41:44,383, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:44,383, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:45,016, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-10-25 14:41:45,016, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-10-25 14:41:47,250, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-25 14:41:47,250, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-25 14:41:47,250, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:47,250, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:47,833, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-10-25 14:41:47,833, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-10-25 14:41:50,082, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-25 14:41:50,082, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-25 14:41:50,087, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:50,087, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:50,899, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-10-25 14:41:50,899, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-10-25 14:41:53,249, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-25 14:41:53,249, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-25 14:41:53,249, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:53,249, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:53,783, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-10-25 14:41:53,783, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-10-25 14:41:55,498, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-25 14:41:55,498, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-25 14:41:55,505, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:55,505, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:56,299, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-10-25 14:41:56,299, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-10-25 14:41:58,716, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-25 14:41:58,716, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-25 14:41:58,716, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-25
# 2024-10-25 14:41:58,716, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:41:59,199, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-10-25 14:41:59,199, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-10-25 14:42:01,532, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-25 14:42:01,532, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-25 14:42:01,532, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-25
# 2024-10-25 14:42:01,532, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:42:02,231, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-10-25 14:42:02,231, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-10-25 14:42:04,482, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-25 14:42:04,482, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-25 14:42:04,482, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-25
# 2024-10-25 14:42:04,482, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:42:05,215, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-10-25 14:42:05,215, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-10-25 14:42:07,465, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-25 14:42:07,465, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-25 14:42:07,482, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-25
# 2024-10-25 14:42:07,482, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:42:08,082, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-10-25 14:42:08,082, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-10-25 14:42:10,365, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-25 14:42:10,365, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-25 14:42:10,382, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-25
# 2024-10-25 14:42:10,382, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:42:11,148, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-10-25 14:42:11,148, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-10-25 14:42:13,581, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-25 14:42:13,581, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-25 14:42:13,581, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-25
# 2024-10-25 14:42:13,581, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:42:14,215, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-10-25 14:42:14,215, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-10-25 14:42:15,732, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-25 14:42:15,732, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-25 14:42:15,732, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-25
# 2024-10-25 14:42:15,732, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-25
# [*********************100%***********************]  1 of 1 completed
# 2024-10-25 14:42:16,132, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-10-25 14:42:16,132, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-10-25 14:42:17,832, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-10-25 14:42:17,832, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Admin\miniconda3\envs\dsi_participant\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
